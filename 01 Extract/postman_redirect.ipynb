# %% [markdown]
# # Extract phase is done with Postman

# %% [markdown]
# ##Go to [02 Transform](https://dbc-8036f0d8-fa2d.cloud.databricks.com/browse/folders/136780767507782?o=2854392045495449) for import related notebooks
