-- %%
SELECT
  *
FROM
  gold.fact_activity
LIMIT 10;

-------

SELECT
  min(activity_date) as min_date,
  max(activity_date) as max_date
FROM
  strava.gold.fact_activity

-----
SELECT *
FROM
  gold.fact_activity
order by cast(activity_date as date) asc
