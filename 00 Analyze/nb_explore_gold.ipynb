# %%
schema = spark.table("strava.gold.fact_activity").schema
print(schema)

# %%
spark.table("strava.gold.fact_activity").printSchema()

# %%
spark.table("strava.silver.activity").printSchema()

# %%
spark.table("strava.bronze.activity").printSchema()
