# %%
#explore tables on silver lakehouse
activity_df = spark.read.table("strava.silver.activity")
gear_df = spark.read.table("strava.silver.gear")
sport_df = spark.read.table("strava.silver.sport")
athlete_df = spark.read.table("strava.silver.athlete")


display(activity_df)
display(gear_df)
display(sport_df)
display(athlete_df)

# %%
# %skip
# %sql
drop table strava.silver.strava_all
